# %% [markdown]
# # Animação da Geração de Dentado por Cremalheira Geradora

# %% [markdown]
# A Importação da Função Desenvolvida em Linguagem Python é executada pelo comando 'import rack'
# Para utilização no computador pessoal, necessita de ter instalado: Python, Numpy e Matplotlib (open source)
# Criada por C. Fernandes em Agosto de 2020
# Disponível em https://github.com/cfernandesFEUP/Machine-Elements-I

# %%
import figures.functions.button
# Out:
#   File "<ipython-input-1-d32e1bc1f5ce>", line 1
#     import ../figures.functions.button
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Como Usar?

# %% [markdown]
# Nas céluas com código "In [ ]", preencha os valores númericos de forma a obter as características da roda dentada desejada. Após introduzir os valores, com o teclado, premir "shift+Enter"

# %% [markdown]
# ## Características da Cremalheira Geradora:

# %% [markdown]
# Ângulo de Pressão [$^\circ$]:

# %%
alpha = 20

# %% [markdown]
# Altura de addendum:

# %%
haP = 1.25

# %% [markdown]
# Altura de deddendum:

# %%
hfP = 1.

# %% [markdown]
# Raio da Ferramenta - $\rho$:

# %%
roh = 0.38

# %% [markdown]
# ## Características da Engrenagem:

# %% [markdown]
# Módulo [mm]:

# %%
m = 3

# %% [markdown]
# Número de dentes:

# %%
z = 20

# %% [markdown]
# Correcção do dentado:

# %%
x = 0

# %% [markdown]
# ## Animação

# %%
# %%capture
# %matplotlib inline
nl = 30   # Número de Incrementos de Rotação
n = 1000  # Número de pontos da cremalheira geradora
import figures.functions.rack as rack
ani = rack.animation(alpha, haP, hfP, roh, m, z, x, nl, n)

# %%
ani
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
# ...
